# %% [markdown]
# # stage3_build_labelling
# This notebook will use a __weak supervision package snorkel__ to generate labels. These labels will be used to train a simple classification model in the next step.
#
# The core task in this notebook is for me to write up a bunch of "Labelling functions", each of them simple, naive and noisy, they are purely based on my biased intuition of what diferent gendered customers may looks like.
#
# Snorkel will then try _"observing when and where these different labeling functions agree or disagree with one another, you can automatically learn—in unsupervised ways—when, where, and how much to trust each of them. You can thus learn their areas of expertise, and the overall level of expertise, so that when you combine their votes you end up with the highest quality label possible for each data point."_
#
# This should work better than any opinionated analysis or heuristics that I can come up in short time.

# %% [markdown]
# # Imports

# %%
from snorkel.labeling import labeling_function
from snorkel.labeling import PandasLFApplier
from snorkel.labeling import LFAnalysis
from snorkel.labeling.model import LabelModel


import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [155], in <cell line: 4>()
#       2 from snorkel.labeling import PandasLFApplier
#       3 from snorkel.labeling import LFAnalysis
# ----> 4 from snorkel.labeling.model import LabelModel
#       7 import pandas as pd
#       8 import numpy as np
#
# File ~/opt/anaconda3/envs/challenge-ilikedata/lib/python3.9/site-packages/snorkel/labeling/model/__init__.py:2, in <module>
#       1 from .baselines import MajorityClassVoter, MajorityLabelVoter, RandomVoter  # noqa: F401
# ----> 2 from .label_model import LabelModel
#
# File ~/opt/anaconda3/envs/challenge-ilikedata/lib/python3.9/site-packages/snorkel/labeling/model/label_model.py:16, in <module>
#      14 from snorkel.labeling.analysis import LFAnalysis
#      15 from snorkel.labeling.model.base_labeler import BaseLabeler
# ---> 16 from snorkel.labeling.model.graph_utils import get_clique_tree
#      17 from snorkel.labeling.model.logger import Logger
#      18 from snorkel.types import Config
#
# File ~/opt/anaconda3/envs/challenge-ilikedata/lib/python3.9/site-packages/snorkel/labeling/model/graph_utils.py:3, in <module>
#       1 from typing import Iterable, List, Tuple
# ----> 3 import networkx as nx
#       6 def get_clique_tree(nodes: Iterable[int], edges: List[Tuple[int, int]]) -> nx.Graph:
#       7     """
#       8     Given a set of int nodes i and edges (i,j), returns a clique tree.
#       9
#    (...)
#      29         An object G representing clique tree
#      30     """
#
# File ~/opt/anaconda3/envs/challenge-ilikedata/lib/python3.9/site-packages/networkx/__init__.py:114, in <module>
#     111 import networkx.relabel
#     112 from networkx.relabel import *
# --> 114 import networkx.generators
#     115 from networkx.generators import *
#     117 import networkx.readwrite
#
# File ~/opt/anaconda3/envs/challenge-ilikedata/lib/python3.9/site-packages/networkx/generators/__init__.py:14, in <module>
#      12 from networkx.generators.expanders import *
#      13 from networkx.generators.geometric import *
# ---> 14 from networkx.generators.intersection import *
#      15 from networkx.generators.joint_degree_seq import *
#      16 from networkx.generators.lattice import *
#
# File ~/opt/anaconda3/envs/challenge-ilikedata/lib/python3.9/site-packages/networkx/generators/intersection.py:13, in <module>
#      11 import random
#      12 import networkx as nx
# ---> 13 from networkx.algorithms import bipartite
#      14 from networkx.utils import py_random_state
#      16 __author__ = "\n".join(['Aric Hagberg (hagberg@lanl.gov)'])
#
# File ~/opt/anaconda3/envs/challenge-ilikedata/lib/python3.9/site-packages/networkx/algorithms/__init__.py:16, in <module>
#      14 from networkx.algorithms.cycles import *
#      15 from networkx.algorithms.cuts import *
# ---> 16 from networkx.algorithms.dag import *
#      17 from networkx.algorithms.distance_measures import *
#      18 from networkx.algorithms.distance_regular import *
#
# File ~/opt/anaconda3/envs/challenge-ilikedata/lib/python3.9/site-packages/networkx/algorithms/dag.py:23, in <module>
#      15 """Algorithms for directed acyclic graphs (DAGs).
#      16
#      17 Note that most of these functions are only guaranteed to work for DAGs.
#      18 In general, these functions do not check for acyclic-ness, so it is up
#      19 to the user to check for that.
#      20 """
#      22 from collections import defaultdict, deque
# ---> 23 from fractions import gcd
#      24 from functools import partial
#      25 from itertools import chain
#
# ImportError: cannot import name 'gcd' from 'fractions' (/Users/muwang/opt/anaconda3/envs/challenge-ilikedata/lib/python3.9/fractions.py)

# %% [markdown]
# # Load data

# %%
features_data_path = "../data/processed/features.parquet"

features = pd.read_parquet(features_data_path)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46279 entries, 0 to 46278
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               46279 non-null  object
#  1   is_newsletter_subscriber  46279 non-null  float64
#  2   cc_payments               46279 non-null  float64
#  3   paypal_payments           46279 non-null  float64
#  4   afterpay_payments         46279 non-null  float64
#  5   apple_payments            46279 non-null  float64
#  6   orders                    46279 non-null  float64
#  7   items                     46279 non-null  float64
#  8   cancels                   46279 non-null  float64
#  9   returns                   46279 non-null  float64
#  10  vouchers                  46279 non-null  float64
#  11  female_items              46279 non-null  float64
#  12  male_items                46279 non-null  float64
#  13  unisex_items              46279 non-null  float64
#  14  wapp_items                46279 non-null  float64
#  15  wftw_items                46279 non-null  float64
#  16  mapp_items                46279 non-null  float64
#  17  wacc_items                46279 non-null  float64
#  18  macc_items                46279 non-null  float64
#  19  mftw_items                46279 non-null  float64
#  20  wspt_items                46279 non-null  float64
#  21  mspt_items                46279 non-null  float64
#  22  curvy_items               46279 non-null  float64
#  23  sacc_items                46279 non-null  float64
#  24  msite_orders              46279 non-null  float64
#  25  desktop_orders            46279 non-null  float64
#  26  android_orders            46279 non-null  float64
#  27  ios_orders                46279 non-null  float64
#  28  other_device_orders       46279 non-null  float64
#  29  work_orders               46279 non-null  float64
#  30  home_orders               46279 non-null  float64
#  31  parcelpoint_orders        46279 non-null  float64
#  32  other_collection_orders   46279 non-null  float64
#  33  redpen_discount_used      46279 non-null  float64
#  34  coupon_discount_applied   46279 non-null  float64
#  35  revenue                   46279 non-null  float64
#  36  days_since_first_order    46279 non-null  float64
#  37  days_since_last_order     46279 non-null  float64
#  38  tenure_months             46279 non-null  float64
#  39  different_addresses       46279 non-null  float64
#  40  shipping_addresses        46279 non-null  float64
#  41  devices                   46279 non-null  float64
#  42  average_discount_onoffer  46279 non-null  float64
#  43  average_discount_used     46279 non-null  float64
# dtypes: float64(43), object(1)
# memory usage: 15.5+ MB

# %% [markdown]
# # Write labelling functions
# I'll come up with as many ideas as I can while exploring the features

# %% [markdown]
# Setup some "constants"

# %%
# ABSTAIN is labelling function's way of saying "I dont' know"
# UNKNOWN is for when there's not enough data, for example customer hasn't bought anything yet
# Sorry, LGBTQI+ community, I don't have enough data or time to account for everyone

MALE = 0
FEMALE = 1
UNKNOWN = 2
ABSTAIN = -1

# %% [markdown]
# Explore the data:

# %%
with pd.option_context('display.max_columns', 999):
    display(features.sample(10))
# Out:
#                             customer_id  is_newsletter_subscriber  \
# 22962  7e6b3e3a57ab92c06f79008a7c1eec69                       1.0
# 25369  3b32ed1d40800cb33affe2e8fa657b85                       0.0
# 44611  2f74aae2d6e670f04be7e0fb843566e1                       1.0
# 4246   facb50c3929e5d94e0a1da0006048e4a                       1.0
# 28274  1fd2335186932f78a197e523f8f1b42a                       1.0
# 9424   07c92ea42367e32709aba581bc5b1501                       0.0
# 30063  310a64113cc54dc223984fd047a3cebb                       1.0
# 45723  1e7f5328bd109c9f2eb5d9802e3d8025                       1.0
# 6256   d1a2b2303f4340b8f01c5897873e405b                       1.0
# 27548  0a60c57abd9c412ab6b42a3b5faa8181                       1.0
#
#        cc_payments  paypal_payments  afterpay_payments  apple_payments  \
# 22962          1.0              0.0                0.0             0.0
# 25369          0.0              1.0                0.0             0.0
# 44611          1.0              0.0                0.0             0.0
# 4246           1.0              1.0                1.0             0.0
# 28274          0.0              1.0                1.0             0.0
# 9424           1.0              1.0                0.0             0.0
# 30063          1.0              0.0                0.0             0.0
# 45723          1.0              0.0                0.0             0.0
# 6256           1.0              0.0                0.0             0.0
# 27548          0.0              1.0                1.0             0.0
#
#          orders     items   cancels   returns  vouchers  female_items  \
# 22962  0.218182  0.381818  0.000000  0.000000  0.018182      0.363636
# 25369  1.000000  1.000000  0.000000  0.000000  0.000000      0.000000
# 44611  0.406250  0.562500  0.000000  0.093750  0.093750      0.562500
# 4246   0.350877  1.000000  0.000000  0.035088  0.087719      1.000000
# 28274  0.714286  1.000000  0.142857  0.000000  0.142857      0.857143
# 9424   0.285714  1.071429  0.000000  0.142857  0.000000      0.428571
# 30063  2.000000  4.000000  0.000000  2.000000  1.000000      0.000000
# 45723  0.235294  0.705882  0.000000  0.000000  0.058824      0.705882
# 6256   0.163636  0.381818  0.000000  0.145455  0.036364      0.381818
# 27548  0.235294  0.294118  0.000000  0.058824  0.000000      0.294118
#
#        male_items  unisex_items  wapp_items  wftw_items  mapp_items  \
# 22962    0.000000      0.018182    0.218182    0.090909    0.000000
# 25369    1.000000      0.000000    0.000000    0.000000    1.000000
# 44611    0.000000      0.000000    0.375000    0.156250    0.000000
# 4246     0.000000      0.000000    0.368421    0.245614    0.000000
# 28274    0.000000      0.142857    0.142857    0.714286    0.000000
# 9424     0.571429      0.071429    0.000000    0.357143    0.428571
# 30063    4.000000      0.000000    0.000000    0.000000    0.000000
# 45723    0.000000      0.000000    0.470588    0.000000    0.000000
# 6256     0.000000      0.000000    0.254545    0.127273    0.000000
# 27548    0.000000      0.000000    0.176471    0.029412    0.000000
#
#        wacc_items  macc_items  mftw_items  wspt_items  mspt_items  \
# 22962    0.000000    0.000000    0.018182    0.054545         0.0
# 25369    0.000000    0.000000    0.000000    0.000000         0.0
# 44611    0.031250    0.031250    0.000000    0.000000         0.0
# 25369                 1.0      1.0                    0.2000
# 44611                 2.0      3.0                    0.0000
# 4246                  5.0      2.0                    0.2098
# 28274                 1.0      2.0                    0.0667
# 9424                  1.0      2.0                    0.2559
# 30063                 1.0      1.0                    0.4249
# 45723                 3.0      1.0                    0.3263
# 6256                  1.0      3.0                    0.1077
# 27548                 2.0      2.0                    0.2500
#
#        average_discount_used
# 22962               0.469517
# 25369               0.200031
# 44611               0.209439
# 4246                0.252050
# 28274               0.078783
# 9424                0.255889
# 30063               0.508165
# 45723               0.383371
# 6256                0.136521
# 27548               0.249972

# %%
features['items'].describe()
# Out:
# count    46279.000000
# mean         1.629684
# std          2.770734
# min          0.029851
# 25%          0.619048
# 50%          1.000000
# 75%          2.000000
# max        232.000000
# Name: items, dtype: float64

# %%
@labeling_function()
def bought_male_item(x):
    return (
        MALE 
        if x.male_items > 0
        else ABSTAIN
    )

@labeling_function()
def bought_more_male_item(x):
    return (
        MALE 
        if x.male_items > x.female_items
        else ABSTAIN
    )

@labeling_function()
def bought_more_female_item(x):
    return (
        FEMALE 
        if x.female_items > x.male_items
        else ABSTAIN
    )

@labeling_function()
def no_purchase(x):
    return (
        UNKNOWN
        if x['items'] == 0
        else ABSTAIN
    )

# %% [markdown]
# # Evaluate labelling functions on feature set - first pass

# %%
labelling_functions = [bought_male_item, bought_more_male_item, bought_more_female_item, no_purchase]
applier = PandasLFApplier(lfs=labelling_functions)
L_train = applier.apply(df=features)
# Out:
# 100%|██████████████████████████████████| 46279/46279 [00:02<00:00, 21343.57it/s]

# %%
coverage_array = (pd.DataFrame(L_train) != ABSTAIN).mean(axis=0)

# %%
LFAnalysis(L=L_train, lfs=labelling_functions).lf_summary()
# Out:
#                          j Polarity  Coverage  Overlaps  Conflicts
# bought_male_item         0      [0]  0.371356  0.352817   0.106463
# bought_more_male_item    1      [0]  0.246354  0.246354   0.000000
# bought_more_female_item  2      [1]  0.689600  0.106463   0.106463
# no_purchase              3       []  0.000000  0.000000   0.000000

# %% [markdown]
# Oops, no_purchase() has 0 coverage, meaning all customers in this dataset has bought something, anyway...

# %% [markdown]
# # Keep writing more labelling functions

# %%
@labeling_function()
def unisex_only(x):
    return (
        UNKNOWN 
        if x.male_items == 0 
            and x.female_items == 0
            and x.unisex_items > 0
        else ABSTAIN
    )

@labeling_function()
def more_than_one_female_categories(x):
    return (
        FEMALE
        if np.sum([
                x.wapp_items > 0, 
                  x.wftw_items > 0, 
                  x.wacc_items > 0,
                  x.wspt_items > 0,
                  x.curvy_items > 0,
        ]) > 1.001
        else ABSTAIN
    )

@labeling_function()
def more_than_one_male_categories(x):
    return (
        MALE
        if np.sum([x.mapp_items > 0, 
                  x.macc_items > 0, 
                  x.mftw_items > 0,
                  x.mspt_items > 0]
                 ) > 1.001
        else ABSTAIN
    )

# %% [markdown]
# # Evaluate labelling functions on feature set - second pass

# %%
labelling_functions = [bought_male_item, bought_more_male_item, bought_more_female_item, no_purchase,
                      unisex_only, more_than_one_female_categories, more_than_one_male_categories
                      ]
applier = PandasLFApplier(lfs=labelling_functions)
L_train = applier.apply(df=features)
# Out:
# 100%|███████████████████████████████████| 46279/46279 [00:06<00:00, 7161.99it/s]

# %%
coverage_array = (pd.DataFrame(L_train) != ABSTAIN).mean(axis=0)

# %%
LFAnalysis(L=L_train, lfs=labelling_functions).lf_summary()
# Out:
#                                  j Polarity  Coverage  Overlaps  Conflicts
# bought_male_item                 0      [0]  0.371356  0.357873   0.120551
# bought_more_male_item            1      [0]  0.246354  0.246354   0.011085
# bought_more_female_item          2      [1]  0.689600  0.328464   0.114501
# no_purchase                      3       []  0.000000  0.000000   0.000000
# unisex_only                      4      [2]  0.045507  0.000324   0.000324
# more_than_one_female_categories  5      [1]  0.323257  0.323257   0.109294
# more_than_one_male_categories    6      [0]  0.139113  0.139113   0.072646

# %% [markdown]
# # Examine conflicts
# Now that we are starting to see more conflicts between different LFs, it'd be good to dive in and see what's happening. It should give me more ideas.

# %%
# how many different votes other than ABSTAIN each example got:
multi_votes = pd.DataFrame(L_train).replace(-1, np.NaN)
multi_votes.columns = [x.name for x in labelling_functions]
multi_votes
# Out:
#        bought_male_item  bought_more_male_item  bought_more_female_item  \
# 0                   0.0                    NaN                      1.0
# 1                   NaN                    NaN                      1.0
# 2                   0.0                    NaN                      1.0
# 3                   NaN                    NaN                      NaN
# 4                   NaN                    NaN                      1.0
# ...                 ...                    ...                      ...
# 46274               0.0                    NaN                      1.0
# 46275               0.0                    NaN                      1.0
# 46276               NaN                    NaN                      1.0
# 46277               NaN                    NaN                      1.0
# 46278               0.0                    NaN                      1.0
#
#        no_purchase  unisex_only  more_than_one_female_categories  \
# 0              NaN          NaN                              1.0
# 1              NaN          NaN                              1.0
# 2              NaN          NaN                              1.0
# 3              NaN          2.0                              NaN
# 4              NaN          NaN                              NaN
# ...            ...          ...                              ...
# 46274          NaN          NaN                              1.0
# 46275          NaN          NaN                              1.0
# 46276          NaN          NaN                              NaN
# 46277          NaN          NaN                              1.0
# 46278          NaN          NaN                              1.0
#
#        more_than_one_male_categories
# 0                                0.0
# 1                                NaN
# 2                                0.0
# 3                                NaN
# 4                                NaN
# ...                              ...
# 46274                            0.0
# 46275                            0.0
# 46276                            NaN
# 46277                            NaN
# 46278                            0.0
#
# [46279 rows x 7 columns]

# %%
multi_votes_filter = (multi_votes.apply(lambda s: s.nunique(), axis=1) > 1)

# %%
with pd.option_context('display.max_columns', 999):
    display(
        pd.concat([
            multi_votes.loc[multi_votes_filter,:],
            features.loc[multi_votes_filter,:]
        ], axis=1).sample(10)
    )
# Out:
#        bought_male_item  bought_more_male_item  bought_more_female_item  \
# 23809               0.0                    NaN                      1.0
# 18087               0.0                    NaN                      NaN
# 25131               0.0                    NaN                      1.0
# 11262               0.0                    NaN                      1.0
# 12694               0.0                    NaN                      1.0
# 36774               0.0                    NaN                      1.0
# 24560               0.0                    0.0                      NaN
# 2510                0.0                    NaN                      1.0
# 26544               0.0                    NaN                      1.0
# 22300               0.0                    NaN                      1.0
#
#        no_purchase  unisex_only  more_than_one_female_categories  \
# 23809          NaN          NaN                              1.0
# 18087          NaN          NaN                              1.0
# 25131          NaN          NaN                              1.0
# 11262          NaN          NaN                              1.0
# 12694          NaN          NaN                              1.0
# 36774          NaN          NaN                              1.0
# 24560          NaN          NaN                              1.0
# 2510           NaN          NaN                              1.0
# 26544          NaN          NaN                              1.0
# 22300          NaN          NaN                              NaN
#
#        more_than_one_male_categories                       customer_id  \
# 23809                            NaN  57511bf7cef5f8e6b9a9d3875793de34
# 18087                            0.0  22d677c7f6e9cad8398328624c03638c
# 25131                            NaN  0317e9e2d5e6c02ae3d45d49d09d5311
# 11262                            NaN  5034edbcf46a1972c5886a024faac566
# 12694                            NaN  facab86622bee27c0d0548af75547782
# 36774                            0.0  b7db819172445ee66d6118ad75c2f1d8
# 24560                            0.0  03d0a618eaf6cda1bfd0f54f76b69d35
# 2510                             NaN  08655a58a87189cb6a8878e596227e12
# 26544                            NaN  3b2a5bcbd1fc634011152892cce852c7
# 22300                            0.0  d9bbb0c203a2c39f3158fe2593272a12
#
#        is_newsletter_subscriber  cc_payments  paypal_payments  \
# 23809                       0.0          1.0              1.0
# 18087                       0.0          0.0              1.0
# 25131                       1.0          1.0              0.0
# 11262                       1.0          1.0              0.0
# 12694                       1.0          0.0              1.0
# 36774                       1.0          1.0              0.0
# 24560                       1.0          1.0              1.0
# 2510                        1.0          1.0              0.0
# 26544                       1.0          0.0              1.0
# 22300                       0.0          1.0              0.0
#
#        afterpay_payments  apple_payments    orders     items   cancels  \
# 23809                0.0             0.0  0.267857  0.446429  0.017857
# 18087                0.0             0.0  0.375000  0.750000  0.000000
# 25131                0.0             0.0  0.833333  1.666667  0.000000
# 11262                0.0             0.0  0.183673  0.346939  0.000000
# 12694                0.0             0.0  0.173913  0.521739  0.000000
# 36774                0.0             0.0  0.692308  1.846154  0.000000
# 24560                0.0             0.0  0.250000  0.583333  0.000000
# 2510                 1.0             0.0  0.163934  0.295082  0.049180
# 26544                0.0             0.0  0.500000  1.166667  0.000000
# 22300                0.0             0.0  2.000000  6.000000  0.000000
#
#         returns  vouchers  female_items  male_items  unisex_items  wapp_items  \
# 23809  0.196429  0.107143      0.392857    0.035714      0.017857    0.285714
# 18087  0.125000  0.125000      0.375000    0.375000      0.000000    0.000000
# 25131  0.166667  0.166667      1.166667    0.333333      0.166667    0.666667
# 11262  0.122449  0.040816      0.326531    0.020408      0.000000    0.244898
# 12694  0.000000  0.043478      0.434783    0.086957      0.000000    0.086957
# 36774  0.230769  0.461538      1.692308    0.076923      0.076923    0.153846
# 24560  0.166667  0.000000      0.145833    0.437500      0.000000    0.083333
# 2510   0.000000  0.016393      0.262295    0.032787      0.000000    0.147541
# 26544  0.500000  0.166667      1.000000    0.166667      0.000000    0.166667
# 22300  0.000000  1.000000      3.000000    2.000000      1.000000    3.000000
#
#        wftw_items  mapp_items  wacc_items  macc_items  mftw_items  wspt_items  \
# 23809    0.071429    0.000000    0.017857    0.017857    0.000000    0.017857
# 18087    0.250000    0.000000    0.125000    0.125000    0.125000    0.000000
# 22300                  1626.0                 1626.0            1.0
#
#        different_addresses  shipping_addresses  devices  \
# 23809                  1.0                 9.0      2.0
# 18087                  0.0                 1.0      1.0
# 25131                  0.0                 1.0      1.0
# 11262                  1.0                 4.0      1.0
# 12694                  0.0                 2.0      1.0
# 36774                  0.0                 2.0      2.0
# 24560                  1.0                 2.0      2.0
# 2510                   1.0                 2.0      1.0
# 26544                  0.0                 2.0      1.0
# 22300                  0.0                 1.0      1.0
#
#        average_discount_onoffer  average_discount_used
# 23809                    0.2679               0.366561
# 18087                    0.1929               0.250094
# 25131                    0.0781               0.279655
# 11262                    0.2420               0.279925
# 12694                    0.4992               0.561999
# 36774                    0.1868               0.390919
# 24560                    0.1724               0.172443
# 2510                     0.1800               0.185283
# 26544                    0.2367               0.283184
# 22300                    0.4332               0.474931

# %% [markdown]
# Here are some observations:
# - customers who bought equal male and female items
# - customers who bought unisex only but also bought men's footwear (is men's footwear unisex?)
# - found some bugs in the LFs
# - customers who bought both male and female, but lean heavily into one side
#
# These give me a few more ideas to try

# %% [markdown]
# # The third round of LFs and evaluation

# %%
@labeling_function()
def two_times_more_female_item(x):
    return (
        FEMALE 
        if x.female_items >= 2.0 * x.male_items
        else ABSTAIN
    )

@labeling_function()
def two_times_more_male_item(x):
    return (
        MALE 
        if x.male_items >= 2.0 * x.female_items
        else ABSTAIN
    )

@labeling_function()
def roughtly_equal_male_female_item(x):
    """My experience tells me this is still more likely female customer :) """
    return (
        FEMALE 
        if x.female_items >= 0.9 * x.male_items
            and x.female_items <= 1.1 * x.male_items
        else ABSTAIN
    )

# %%
labelling_functions = [bought_male_item, bought_more_male_item, bought_more_female_item, no_purchase,
                      unisex_only, more_than_one_female_categories, more_than_one_male_categories,
                       two_times_more_female_item, two_times_more_male_item, roughtly_equal_male_female_item
                      ]
applier = PandasLFApplier(lfs=labelling_functions)
L_train = applier.apply(df=features)
# Out:
# 100%|███████████████████████████████████| 46279/46279 [00:08<00:00, 5429.18it/s]

# %%
coverage_array = (pd.DataFrame(L_train) != ABSTAIN).mean(axis=0)

# %%
LFAnalysis(L=L_train, lfs=labelling_functions).lf_summary()
# Out:
#                                  j Polarity  Coverage  Overlaps  Conflicts
# bought_male_item                 0      [0]  0.371356  0.371356   0.136088
# bought_more_male_item            1      [0]  0.246354  0.246354   0.011085
# bought_more_female_item          2      [1]  0.689600  0.689600   0.114501
# no_purchase                      3       []  0.000000  0.000000   0.000000
# unisex_only                      4      [2]  0.045507  0.045507   0.045507
# more_than_one_female_categories  5      [1]  0.323257  0.323257   0.109294
# more_than_one_male_categories    6      [0]  0.139113  0.139113   0.074699
# two_times_more_female_item       7      [1]  0.724411  0.724411   0.149312
# two_times_more_male_item         8      [0]  0.283347  0.283347   0.051600
# roughtly_equal_male_female_item  9      [1]  0.064392  0.064392   0.064392

# %% [markdown]
# # Combine all LFs to generate a statistical labelling model
# It can get much more sophisticated than that, for example with expert inputs from SMEs. But I'm clearly no SME in this area, thinking on it even more might have diminished return.
#
# I think that's good enough given the time spent
#
# Time to generate Labels!
